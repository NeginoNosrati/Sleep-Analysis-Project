# %% [markdown]
# <a href="https://colab.research.google.com/github/NeginoNosrati/Sleep-Analysis-Project/blob/main/Sleep_Analysis_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('Sleep_Efficiency.csv')
data.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
data.sample(13)
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 243  244   52    Male  2021-09-14 00:00:00  2021-09-14 07:00:00
# 86    87   50    Male  2021-04-09 00:00:00  2021-04-09 07:00:00
# 127  128   37  Female  2021-05-15 23:00:00  2021-05-15 06:00:00
# 355  356   39    Male  2021-10-26 02:30:00  2021-10-26 09:30:00
# 349  350   24  Female  2021-12-04 21:30:00  2021-12-04 05:00:00
# 69    70   40    Male  2021-09-23 22:00:00  2021-09-23 04:00:00
# 437  438   56    Male  2021-03-11 01:00:00  2021-03-11 09:00:00
# 441  442   46    Male  2021-03-30 00:00:00  2021-03-30 09:00:00
# 157  158   45  Female  2021-07-20 21:00:00  2021-07-20 04:00:00
# 295  296   29  Female  2021-10-09 01:00:00  2021-10-09 09:00:00
# 100  101   38  Female  2021-09-02 00:30:00  2021-09-02 08:30:00
# 249  250   61    Male  2021-04-04 00:30:00  2021-04-04 10:30:00
# 227  228   29  Female  2021-09-12 21:30:00  2021-09-12 04:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# ...

# %%
data.shape
# Out:
# (452, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %%
data.describe()
# Out:
#                ID         Age  Sleep duration  Sleep efficiency  \
# count  452.000000  452.000000      452.000000        452.000000
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count            452.000000             452.000000              452.000000
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# ...

# %%
#does caffeine affect sleep efficiency?
caffeine_efficiency_data = data[['Caffeine consumption', 'Sleep efficiency']]
data.describe()
avg_efficiency_by_caffeine = caffeine_efficiency_data.groupby('Caffeine consumption')['Sleep efficiency'].mean()

print(avg_efficiency_by_caffeine)
# Out:
# Caffeine consumption
# 0.0      0.786209
# 25.0     0.799114
# 50.0     0.771589
# 75.0     0.845600
# 100.0    0.900000
# 200.0    0.882500
# Name: Sleep efficiency, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = data_cleaned[['Caffeine consumption']]

Y = data_cleaned[['Sleep efficiency']]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# وارد کردن مدل رگرسیون خطی

# %%
data.isnull().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       14
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
data_cleaned = data.dropna()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
perdiction = model.predict(X_test)

print("models prediction:")
print(perdiction[:5])
# Out:
# models prediction:
# [[0.79350756]
#  [0.78754399]
#  [0.78754399]
#  [0.78754399]
#  [0.78754399]]

# %%
score = model.score(X_test, Y_test)
print(f"score: {score}")
# Out:
# score: -0.007124291211891176

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))

plt.scatter(X_test, Y_test, color='red', label='real dats')

plt.plot(X_test, perdiction, color='blue', label='prediction')

plt.title('REAL DATA vr PREDICTIONS')
plt.xlabel('caffine consumption')
plt.ylabel('sleep efficiency')

plt.legend()
plt.show()
